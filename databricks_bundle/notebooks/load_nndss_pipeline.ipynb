# %% [markdown]
# ## Lakeflow Declarative Pipeline Sample
# Loads the data from the CDC NNDSS into Databricks

# %%
import dlt
@dlt.table(name='nndss_raw')
def load_nndss_data():
    return (spark.read.parquet("/Volumes/health_data/nndss/nndss_staging/nndss/nndss/"))
